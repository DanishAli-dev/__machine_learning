# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_moons
from sklearn.cluster import KMeans,DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
X, y_true = make_moons(n_samples=500, noise=0.05, random_state=42)

# %%
df = pd.DataFrame(X, columns=['Feature_1', 'Feature_2'])

# %%
df
# Out:
#      Feature_1  Feature_2
# 0     0.830586  -0.447733
# 1     0.701678   0.816918
# 2     1.022080  -0.492571
# 3    -0.316765   0.953438
# 4     0.293226   1.057185
# ..         ...        ...
# 495   0.239754   0.985462
# 496   0.072145   0.184834
# 497   0.590273  -0.365577
# 498   1.619465  -0.283658
# 499   0.228960   1.063974
#
# [500 rows x 2 columns]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels = kmeans.fit_predict(X_scaled)

# %%
df['kmenans_cluster'] = kmeans_labels

# %%
sns.scatterplot(data=df, x='Feature_1', y='Feature_2', hue='kmenans_cluster')
plt.show()

# %%
dbscan = DBSCAN(eps=0.3, min_samples=5)
dbscan_labels = dbscan.fit_predict(X_scaled)

# %%
df['dbscan_clusters'] = dbscan_labels

# %%
sns.scatterplot(data=df, x='Feature_1', y='Feature_2', hue='dbscan_clusters')
plt.show()
